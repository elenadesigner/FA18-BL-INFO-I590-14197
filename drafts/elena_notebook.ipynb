# %% [markdown]
# Phase 1

# %%
import pandas as pd
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

# %%
pd.read_csv
pd.read_csv("Breast-Cancer-Wisconsin.csv") 
df.head()
# Out:
#        Scn  A2  A3  A4  A5  A6    A7  A8  A9  A10  CLASS
# 0  1000025   5   1   1   1   2   1.0   3   1    1      2
# 1  1002945   5   4   4   5   7  10.0   3   2    1      2
# 2  1015425   3   1   1   1   2   2.0   3   1    1      2
# 3  1016277   6   8   8   1   3   4.0   3   7    1      2
# 4  1017023   4   1   1   3   2   1.0   3   1    1      2

# %%
df["A7"] = df["A7"].replace('?', np.NaN) #Replace ? by NaN in column A7

# %%
df["A7"] = pd.to_numeric(df['A7']) #Apply pandas function pd.to_numeric() for column A7

# %%
print (df.isnull().sum())
print ("There are", df['A7'].isnull().sum(), "NaN")#Report how many NaN
# Out:
# Scn       0
# A2        0
# A3        0
# A4        0
# A5        0
# A6        0
# A7       16
# A8        0
# A9        0
# A10       0
# CLASS     0
# dtype: int64
# There are 16 NaN

# %%
df.fillna(df["A7"].mean(skipna=True)) #Replace NaN values with the mean of column A7
# Out:
#          Scn  A2  A3  A4  A5  A6         A7  A8  A9  A10  CLASS
# 0    1000025   5   1   1   1   2   1.000000   3   1    1      2
# 1    1002945   5   4   4   5   7  10.000000   3   2    1      2
# 2    1015425   3   1   1   1   2   2.000000   3   1    1      2
# 3    1016277   6   8   8   1   3   4.000000   3   7    1      2
# 4    1017023   4   1   1   3   2   1.000000   3   1    1      2
# 5    1017122   8  10  10   8   7  10.000000   9   7    1      4
# 6    1018099   1   1   1   1   2  10.000000   3   1    1      2
# 7    1018561   2   1   2   1   2   1.000000   3   1    1      2
# 8    1033078   2   1   1   1   2   1.000000   1   1    5      2
# 9    1033078   4   2   1   1   2   1.000000   2   1    1      2
# 10   1035283   1   1   1   1   1   1.000000   3   1    1      2
# 11   1036172   2   1   1   1   2   1.000000   2   1    1      2
# 12   1041801   5   3   3   3   2   3.000000   4   4    1      4
# 13   1043999   1   1   1   1   2   3.000000   3   1    1      2
# ...

# %%
print (df.describe()) #Provide the summary statistics
# Out:
#                 Scn          A2          A3          A4          A5  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#                A6          A7          A8          A9         A10       CLASS
# count  699.000000  683.000000  699.000000  699.000000  699.000000  699.000000
# mean     3.216023    3.544656    3.437768    2.866953    1.589413    2.689557
# std      2.214300    3.643857    2.438364    3.053634    1.715078    0.951273
# ...

# %%
print(df.shape) #Find number of columns and number of rows
# Out:
# (699, 11)

# %%
number_cols = len(df.columns)
number_rows = len(df.index)

# %%
print ("There are", number_cols, "number of columns and", number_rows, "number of rows") #Report how many observations (row) and columns
# Out:
# There are 11 number of columns and 699 number of rows

# %%
print(len(df.Scn.unique())) #Report how many unique id values (column Scn)
# Out:
# 645

# %%
pd.DataFrame.hist(df.loc[:, 'A2':'A10'], grid = False, color = 'y') #Draw histograms for columns A2-A10
plt.tight_layout(rect=(0, 0, 1, 1))
plt.show()

# %%
df2 = pd.value_counts(df['CLASS'].values)

# %%
print (df2)
# Out:
# 2    458
# 4    241
# dtype: int64

# %%
benign = df2[2]
malignant = df2[4]

# %%
#Draw a bar plot for CLASS
df2[[benign,malignant]]
plt.title('Bar plot')
plt.xlabel('Categories')
plt.ylabel('Values')

df2.plot.bar(color = (0.2,0.1,0.4))
plt.show()

# %%
#Draw a scatterplot of any two columns
normal_nuclei = df['A9']
mitosis = df['A10']
plt.title('Pattern Separation Scatterplot')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.scatter(normal_nuclei, mitosis, c='DarkBlue')
plt.show()
